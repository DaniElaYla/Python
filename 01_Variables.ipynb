# %%
### Variables ###
#my_string_variable = "my string variable"
#print(my_string_variable)

#my_int_variable = 5
#print(my_int_variable)
#my_int_to_str_variable = str(my_int_variable)
#print(my_int_to_str_variable)
#print(type(my_int_to_str_variable))

#my_bool_variable = False
#print(my_bool_variable)

# Concatenacion de variables en un print
#print(my_string_variable, my_int_to_str_variable, my_bool_variable)
#print("Este es el valor de", my_bool_variable)

# Algunas funciones del sistema
#print(len(my_string_variable))

#n Variables en una sola linea. ¡Cuidado con abusar de este sintaxis!
#name, surname, alias, age = "grupo", "peogramacion", 'CECyTEM', 35
#print("me llamo:", name, surname, ". Min edad es:",
#      age, "y el alias es:", alias)

# Inputs
#name = input('¿Cual es tu nambre?  ')
#age = input('¿Cuantos años tienes?  ')
#print(name)
#print(age)

# ¿Forzamos el tipo?
address: str = "My direccion"
address = True
address = 5
address = 1.2
print(type(address))
# Out:
# <class 'float'>
