# %%
### Lista ###
# Definicion

# My other list
my_list = list()
my_other_list = []

print(len(my_list))

my_list = [34, 58, 67, 15, 30, 54, 82]
print(my_list)
print(len(my_list))

my_other_list = [16, 1.53, "Dani", "Ayala"]

print(type(my_list))
print(type(my_other_list))


#Acceso a elementos y busqueda

print(my_other_list[0])
print(my_other_list[1])
print(my_other_list[-1])
print(my_other_list[-4])
print(my_list.count(30))
#print(my_other_list[4]) IndexError
#print(my_other_list[-5]) IndexError

#print(my_other_list("Dani")) IndexError

age, height, name, surname = my_other_list
print(name)

name, height, age, surname = my_other_list[2], my_other_list[1], my_other_list[0], my_other_list[3]
print(age)

#Concatenacion

print(my_list + my_other_list)
#print(my_list + my_other_list)

# Creacion, insercion, actualizacion y eliminacion

my_other_list.append("CECyTEM") #se agrega al final de la lista
print(my_other_list)

my_other_list.insert(1, "Rojo") #se posisiona en la posicion 1
print(my_other_list)

my_other_list[1] = "Azul" #se remplaza en la posicion 1
print(my_other_list)

my_other_list.remove("Azul")
print(my_other_list)

my_list.remove(30)
print(my_list)

print(my_list.pop())
print(my_list) #muestra el ultimo elemento eliminado

my_pop_element = my_list.pop(2)
print(my_pop_element)
print(my_list)

del my_list[2]
print(my_list)

#Operadores con listas

my_new_list = my_list.copy()

my_list.clear()
print(my_list)
print(my_new_list)

my_new_list.reverse()
print(my_new_list)

# Sublistas

print(my_new_list[1:3])

# Cambio de tipo

my_list = "Hola Python"
print(my_list)
print(type(my_list))
# Out:
# 0
# [34, 58, 67, 15, 30, 54, 82]
# 7
# <class 'list'>
# <class 'list'>
# 16
# 1.53
# Ayala
# 16
# 1
# Dani
# 16
# [34, 58, 67, 15, 30, 54, 82, 16, 1.53, 'Dani', 'Ayala']
# [16, 1.53, 'Dani', 'Ayala', 'CECyTEM']
# [16, 'Rojo', 1.53, 'Dani', 'Ayala', 'CECyTEM']
# [16, 'Azul', 1.53, 'Dani', 'Ayala', 'CECyTEM']
# [16, 1.53, 'Dani', 'Ayala', 'CECyTEM']
# [34, 58, 67, 15, 54, 82]
# 82
# [34, 58, 67, 15, 54]
# 67
# [34, 58, 15, 54]
# [34, 58, 54]
# []
# [34, 58, 54]
# [54, 58, 34]
# [58, 34]
# Hola Python
# <class 'str'>
