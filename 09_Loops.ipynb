# %%
### While
my_condition = 0

while my_condition < 10:
  print(my_condition)
  my_condition += 2
else: #Es opcional
  print("Mi condicion es mayor o igual que 10")

print("La ejecucion continua")

while my_condition < 20:
  my_condition += 1
  if my_condition == 15:
    print("Se detiene la ejecucion")
    break
  print(my_condition)

print("La ejecucion continua")

# for

#my_list = [35, 24, 62, 52, 30, 17]

#for element in my_list:
 # print(element)

#my_tuple = (16, 1.53, "Dani", "Ayala", "Dani")

#for element in my_tuple:
 # print(element)

#my_set = {"Dani", "Ayala", 16}

#for element in my_set:
 # print(element)

my_dict = {"Nombre": "Dani", "Apellido": "Ayala", "Edad": 35, 1: "Python"}

for element in my_dict:
  print(element)
  if element == "Edad":
     break
else:
  print("El bluce for para diccionario ha finalizado")

my_dict = {"Nombre": "Dani", "Apellido": "Ayala", "Edad": 35, 1: "Python"}

for element in my_dict:
  print(element)
  if element == "Edad":
     continue
     print("Se ejecuta")
else:
  print("El bluce for para diccionario ha finalizado")
# Out:
# 0
# 2
# 4
# 6
# 8
# Mi condicion es mayor o igual que 10
# La ejecucion continua
# 11
# 12
# 13
# 14
# Se detiene la ejecucion
# La ejecucion continua
# Nombre
# Apellido
# Edad
# Nombre
# Apellido
# Edad
# 1
# El bluce for para diccionario ha finalizado
